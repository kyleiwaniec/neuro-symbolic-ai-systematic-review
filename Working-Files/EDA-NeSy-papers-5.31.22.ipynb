# %% [markdown]
# # Final Articles

# %%
import pandas as pd
import numpy as np
import itertools
from collections import defaultdict

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.style.use('presentation.mplstyle')
mpl.matplotlib_fname()
# Out:
# '/Users/kylehamilton/MyDocuments/ML-Labs/neuro-symbolic-AI/neuro-symbolic-ai-systematic-review/Working-Files/matplotlibrc'

# %%
df=pd.read_csv('Data/NeSy-Review-Papers - 5.31.22.csv')

# %%
len(df)
# Out:
# 61

# %%
(df).columns
# Out:
# Index(['Doc type', 'citation', 'Title', 'Abstract', 'Scopus Hash ID', 'DOI',
#        'Journal/Conference', 'Year', 'Business Use Case',
#        'Technical Application', 'Type of Learning', 'Key-intake',
#        'Contribution', 'Authors Definition of NeSy', 'Symbolic terms',
#        'Neural terms', 'NeSy Category', 'Kautz category', 'Datasets',
#        'Model description', 'Evaluation Metrics', 'Reported Score',
#        'Study Quality', 'Comments', 'MISC',
#        'leverages natural language structure',
#        'leverages relational structure', 'Knowledge representation',
#        'implicit vs explicit', 'reasoning',
#        'out-of-distribution generalization', 'interpretability',
#        'reduced data', 'transferability',
#        'NeSy (check if the authors label their work as NeSy)', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
df=df[['Doc type', 'citation', 'Title', 'Abstract', 'Scopus Hash ID', 'DOI',
       'Journal/Conference', 'Year', 'Business Use Case',
       'Technical Application', 'Type of Learning', 'Key-intake',
       'Contribution', 'Authors Definition of NeSy', 'Symbolic terms',
       'Neural terms', 'NeSy Category', 'Kautz category', 'Datasets',
       'Model description', 'Evaluation Metrics', 'Reported Score',
       'Study Quality', 'Comments', 'MISC',
       'leverages natural language structure',
       'leverages relational structure', 'Knowledge representation',
       'implicit vs explicit', 'reasoning',
       'out-of-distribution generalization', 'interpretability',
       'reduced data', 'transferability',
       'NeSy (check if the authors label their work as NeSy)']]

# %%
plt.hist(df['Year'])
plt.title('Publication Year Distribution')
plt.xlabel('Publication Year')
plt.ylabel('Number of Articles')
plt.show()

# %%
df['Business Use Case'].value_counts()
# Out:
# Question answering                 10
# Text classification                 7
# Reading comprehension               5
# KG Completion / link prediction     5
# Sentiment analysis                  5
# Causal Reasoning                    3
# Annotation                          3
# Information extraction              3
# Decision support                    2
# Dialog system                       2
# Language modeling                   2
# N2F                                 2
# Text games                          2
# Relation extraction                 2
# Entity Linking                      1
# Emotion recognition                 1
# Translation                         1
# Image captioning                    1
# Entity Resolution                   1
# Opnion extraction                   1
# Argumentation mining                1
# Text summarization                  1
# Name: Business Use Case, dtype: int64

# %%
df['Business Use Case'].value_counts().plot(kind='barh', title="Number of Articles per Use Case")
# Out:
# <AxesSubplot:title={'center':'Number of Articles per Use Case'}>

# %%
df['Type of Learning'].value_counts().plot(kind='barh', title="Number of articles per type of learning")
# Out:
# <AxesSubplot:title={'center':'Number of articles per type of learning'}>

# %%
app_value_counts = df['Technical Application'].value_counts()

# %%
app_value_counts
# Out:
# classification                35
# information extraction         7
# generative                     7
# reasoning                      7
# inference                      3
# classification,\ninference     1
# similarity                     1
# Name: Technical Application, dtype: int64

# %%
app_value_counts['inference']+=app_value_counts['classification,\ninference']
app_value_counts['classification']+=app_value_counts['classification,\ninference']

# %%
app_value_counts.pop('classification,\ninference')
# Out:
# 1

# %%
app_value_counts
# Out:
# classification            36
# information extraction     7
# generative                 7
# reasoning                  7
# inference                  4
# similarity                 1
# Name: Technical Application, dtype: int64

# %%
app_value_counts.plot(kind='barh', title="Number of articles per application")
# Out:
# <AxesSubplot:title={'center':'Number of articles per application'}>

# %%
nesy_value_counts = df['NeSy Category'].value_counts()

# %%
nesy_value_counts
# Out:
# sequential     23
# compiled       18
# cooperative    13
# nested          7
# Name: NeSy Category, dtype: int64

# %%
nesy_value_counts.plot(kind='barh', title="Number of articles per NeSy Category")
# Out:
# <AxesSubplot:title={'center':'Number of articles per NeSy Category'}>

# %%
df['Kautz category'].value_counts().plot(kind='barh', title="Number of articles per Kautz category")
# Out:
# <AxesSubplot:title={'center':'Number of articles per Kautz category'}>
# /Users/kylehamilton/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8594 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kylehamilton/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8594 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df['Kautz category'].value_counts()
# Out:
# 1. symbolic Neuro symbolic    23
# 3. Neuro; Symbolic            13
# 4. Neuro: Symbolic → Neuro     9
# 5. Neuro_Symbolic              8
# 6. Neuro[Symbolic]             5
# 2. Symbolic[Neuro]             3
# Name: Kautz category, dtype: int64

# %%
seq_df = df[df['NeSy Category']=='sequential']

# %%
app_value_counts = seq_df['Technical Application'].value_counts()

# %%
app_value_counts
# Out:
# classification            16
# reasoning                  2
# information extraction     2
# similarity                 1
# generative                 1
# inference                  1
# Name: Technical Application, dtype: int64

# %%
app_value_counts.plot(kind='barh', title="Number of articles per application\nin the Sequential category")
plt.savefig("images/seq_category.svg", format="svg")

# %%
df['Symbolic terms'].unique()
# Out:
# array(['first order logic (FOL),\nGrounding,\nfactor graph',
#        'dependency parsing', 'semantic parsing',
#        'first order logic (FOL),\nontology', 'case based reasoning (CBR)',
#        'temporal logic', 'knowledge graph (KG)', 'graph representation',
#        'rule induction',
#        'first order logic (FOL),\nontology,\nsemantic parsing,\nrule based',
#        'Natural Logic', 'first order logic (FOL)',
#        'knowledge graph (KG),\nontology',
#        'ontology,\nfirst order logic (FOL)', 'semantic net',
#        'first order logic (FOL),\nknowledge graph (KG)',
#        'semantic enrichement',
#        'dependency parsing,\nconstituency parsing',
#        'dependency parsing,\ngraph reasoning,\ngraph representation',
#        'Vector-symbolic architecture',
#        'semantic enrichement,\ninductive logic prgramming (ILP),\nfirst order logic (FOL),\nontology',
#        'rule based', 'fuzzy logic', 'path finding and reasoning',
#        'semantic enrichment', 'sememe',
#        'symbolic learner,\nsymbolic representations,\nConceptNet KG',
#        'logic', 'first order logic (FOL),\nHuffman tree',
#        'commonsense knowledge,\ngraph representation',
#        'Sequencial decision making,\npredicate logic,\nrelational logic,\nrule based,\nrule induction,\ncognitive linguistics',
#        'fuzzy logic,\nfuzzy neural network (FNN),\nlogical connectives',
#        'fuzzy logic,\nNeutrosophy', 'symbolic processing',
#        'fuzzy logic,\nfuzzy rules,\nmamdani fuzzy system (MFS)',
#        'constituency parsing', 'graph representation,\ngraph reasoning',
#        'ontology',
#        'domain specific language (DSL),\ntransductive learning,\nprogram synthesis',
#        'fuzzy logic,\nfuzzy rules', 'domain specific language (DSL)',
#        'symbolic node embedding,\ngraph representation,\nsemantic parsing',
#        'binding problem', 'rule based,\nsemantic enrichment'],
#       dtype=object)

# %%
df['Neural terms'].unique()
# Out:
# array(['long short term memory (LSTM),\nTransE,\ntransformer,\nrecurrent neural network (RNN)',
#        'transformer', 'graph neural network (GNN)',
#        'recurrent neural network (RNN), recurrent neural network (RNN),\nBiDAF',
#        'Gated Neural Network, recurrent neural network (RNN)',
#        'recurrent neural network (RNN), recurrent neural network (RNN), tranformer',
#        'convolutional neural network (CNN)', 'Logical Neural Network',
#        'TransE,\ntransformer',
#        'recurrent neural network (RNN),\ntransformer', nan,
#        'Logical Neural Network,\ntransformer',
#        'recurrent neural network (RNN)',
#        'graph neural network (GNN),\ntransformer', 'SVM',
#        'neural network (NN)', 'logic tensor network (LTN)',
#        'SVM,\nneuroevolution (NE)',
#        'recursive neural knowledge network (RNKN),\nrecursive neural network (RcNN)',
#        'reinforcement learning (RL),\nMemory Network,\nneural network (NN)\n',
#        'convolutional neural network (CNN),\nrecurrent neural network (RNN),\ndeep belief network (DBN)',
#        'convolutional neural network (CNN),\nrecurrent neural network (RNN)',
#        'convolutional neural network (CNN),\nneural network (NN)',
#        'attention network (Attn),\ngraph neural network (GNN)',
#        'recurrent neural network (RNN),\nreinforcement learning (RL)',
#        'recursive neural network (RcNN),\nTensor Product Representation (TPR)',
#        'recurrent neural network (RNN),\nconvolutional neural network (CNN),\nattention network (Attn)',
#        'Tensor Product Representation (TPR),\nrecurrent neural network (RNN)'],
#       dtype=object)

# %%
df['Study Quality'].str.rstrip('%').astype('float').plot(kind='hist',title="study quality")
# Out:
# <AxesSubplot:title={'center':'study quality'}, ylabel='Frequency'>

# %%
df['Datasets'].value_counts()
# Out:
# Private                                                                                                                                                                               3
# DBpedia                                                                                                                                                                               2
# SemEval-2010                                                                                                                                                                          1
# Gigaword,\nDUC 2004,\nCNN/DailyMail                                                                                                                                                   1
# Medical Guideline Central, word2vec -> lstm (5 class prediction for each word) -> 125 successfully obtained fuzzy rules in the fuzzy rules database in MATLAB -> defuzzification\n    1
# DialogRE                                                                                                                                                                              1
# QA-S,\nQA-L                                                                                                                                                                           1
# LOINC                                                                                                                                                                                 1
# WN18                                                                                                                                                                                  1
# ClueWeb, Freebase                                                                                                                                                                     1
# Coin collecter                                                                                                                                                                        1
# DropQA, Math23k                                                                                                                                                                       1
# multiple, multi-modal                                                                                                                                                                 1
# COPA benchmark set (Choice of Plausible Alternatives)                                                                                                                                 1
# sentiment140, sentiment140,\nCOVID-19_Sentiments                                                                                                                                      1
# FB15K, WN18                                                                                                                                                                           1
# TRACIE                                                                                                                                                                                1
# SemEval 2014,\nSemEval 2016                                                                                                                                                           1
# Pang and Lee,\nAffectNet benchmark                                                                                                                                                    1
# bAbI-20                                                                                                                                                                               1
# SEMAINE, IEMOCAP, MELD                                                                                                                                                                1
# MIER-19                                                                                                                                                                               1
# SoMoral                                                                                                                                                                               1
# Æthel                                                                                                                                                                                 1
# ScholarlyRead                                                                                                                                                                         1
# Reuters Corpus Volume 1, RCV1-2K, AmazonCat-13K                                                                                                                                       1
# WebQuestionsSP,\nTriviaQA                                                                                                                                                             1
# SICK                                                                                                                                                                                  1
# Spider                                                                                                                                                                                1
# Kinsources, Geoquery                                                                                                                                                                  1
# CLEVR                                                                                                                                                                                 1
# MultiWOZ 2.0                                                                                                                                                                          1
# COMPLEXWEBQUESTIONS                                                                                                                                                                   1
# COCO, Penn TreeBank                                                                                                                                                                   1
# AffectiveText, ISEAR, and Fairy Tales, Facebook posts                                                                                                                                 1
# ProppLearner, Inscript                                                                                                                                                                1
# Wikitext                                                                                                                                                                              1
# SemEval 2016                                                                                                                                                                          1
# CM17K, Math23K                                                                                                                                                                        1
# CRAFT                                                                                                                                                                                 1
# Liar data set                                                                                                                                                                         1
# DROP,\nRACE                                                                                                                                                                           1
# debate.org                                                                                                                                                                            1
# FB15K                                                                                                                                                                                 1
# TextWorld                                                                                                                                                                             1
# SemEval 2014                                                                                                                                                                          1
# ChatWorks                                                                                                                                                                             1
# SQuAD,\nSNLI,\nCoNLL2000                                                                                                                                                              1
# MDG-C, MDG-D                                                                                                                                                                          1
# semeval2019, semeval2019,\nmbti,\nFox,\nBBC,\netc..                                                                                                                                   1
# SemEval 2020                                                                                                                                                                          1
# reACE,\nIPEA                                                                                                                                                                          1
# BBC News database, BBC SPORTS database, Kaagle news                                                                                                                                   1
# LC-QuAD 1.0\nQALD-9\nWebQSP\n                                                                                                                                                         1
# Dagstuhl15512 ArgQuality                                                                                                                                                              1
# MathQA                                                                                                                                                                                1
# CEMR                                                                                                                                                                                  1
# TREC                                                                                                                                                                                  1
# Name: Datasets, dtype: int64

# %%
# symbolic terms
sym_terms=df['Symbolic terms']
sym_list=[[i.strip(' ').rstrip(',') for i in str(s).split("\n")] for s in sym_terms]

# %%
sym_list
# Out:
# [['first order logic (FOL)', 'Grounding', 'factor graph'],
#  ['dependency parsing'],
#  ['semantic parsing'],
#  ['first order logic (FOL)', 'ontology'],
#  ['case based reasoning (CBR)'],
#  ['temporal logic'],
#  ['knowledge graph (KG)'],
#  ['graph representation'],
#  ['rule induction'],
#  ['first order logic (FOL)', 'ontology', 'semantic parsing', 'rule based'],
#  ['Natural Logic'],
#  ['case based reasoning (CBR)'],
#  ['first order logic (FOL)'],
#  ['knowledge graph (KG)', 'ontology'],
#  ['ontology', 'first order logic (FOL)'],
#  ['semantic net'],
#  ['first order logic (FOL)', 'knowledge graph (KG)'],
#  ['graph representation'],
#  ['semantic net'],
#  ['semantic enrichement'],
#  ['dependency parsing', 'constituency parsing'],
#  ['first order logic (FOL)'],
#  ['first order logic (FOL)'],
#  ['dependency parsing', 'graph reasoning', 'graph representation'],
#  ['Vector-symbolic architecture'],
#  ['semantic net'],
#  ['semantic enrichement',
#   'inductive logic prgramming (ILP)',
#   'first order logic (FOL)',
#   'ontology'],
#  ['rule based'],
#  ['fuzzy logic'],
#  ['Vector-symbolic architecture'],
#  ['path finding and reasoning'],
#  ['semantic enrichment'],
#  ['first order logic (FOL)'],
#  ['first order logic (FOL)', 'knowledge graph (KG)'],
#  ['semantic enrichment'],
#  ['sememe'],
#  ['symbolic learner', 'symbolic representations', 'ConceptNet KG'],
#  ['logic'],
#  ['first order logic (FOL)', 'Huffman tree'],
#  ['commonsense knowledge', 'graph representation'],
#  ['knowledge graph (KG)'],
#  ['Sequencial decision making',
#   'predicate logic',
#   'relational logic',
#   'rule based',
#   'rule induction',
#   'cognitive linguistics'],
#  ['fuzzy logic', 'fuzzy neural network (FNN)', 'logical connectives'],
#  ['fuzzy logic', 'Neutrosophy'],
#  ['symbolic processing'],
#  ['semantic net'],
#  ['fuzzy logic', 'fuzzy rules', 'mamdani fuzzy system (MFS)'],
#  ['case based reasoning (CBR)'],
#  ['rule based'],
#  ['constituency parsing'],
#  ['graph representation', 'graph reasoning'],
#  ['ontology'],
#  ['domain specific language (DSL)',
#   'transductive learning',
#   'program synthesis'],
#  ['fuzzy logic', 'fuzzy rules'],
#  ['domain specific language (DSL)'],
#  ['rule based'],
#  ['constituency parsing'],
#  ['semantic enrichment'],
#  ['symbolic node embedding', 'graph representation', 'semantic parsing'],
#  ['binding problem'],
#  ['rule based', 'semantic enrichment']]

# %%
neu_terms=df['Neural terms']
neu_list=[[i.rstrip(',') for i in str(s).split("\n")] for s in neu_terms]

# %%
neu_list
# Out:
# [['long short term memory (LSTM)',
#   'TransE',
#   'transformer',
#   'recurrent neural network (RNN)'],
#  ['transformer'],
#  ['graph neural network (GNN)'],
#  ['recurrent neural network (RNN), recurrent neural network (RNN)', 'BiDAF'],
#  ['Gated Neural Network, recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN), recurrent neural network (RNN), tranformer'],
#  ['transformer'],
#  ['convolutional neural network (CNN)'],
#  ['Logical Neural Network'],
#  ['Logical Neural Network'],
#  ['transformer'],
#  ['TransE', 'transformer'],
#  ['transformer'],
#  ['recurrent neural network (RNN)', 'transformer'],
#  ['transformer'],
#  ['nan'],
#  ['Logical Neural Network', 'transformer'],
#  ['recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN)'],
#  ['transformer'],
#  ['recurrent neural network (RNN)'],
#  ['transformer'],
#  ['graph neural network (GNN)', 'transformer'],
#  ['transformer'],
#  ['SVM'],
#  ['neural network (NN)'],
#  ['neural network (NN)'],
#  ['recurrent neural network (RNN)'],
#  ['neural network (NN)'],
#  ['graph neural network (GNN)'],
#  ['recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN)'],
#  ['logic tensor network (LTN)'],
#  ['graph neural network (GNN)'],
#  ['neural network (NN)'],
#  ['SVM', 'neuroevolution (NE)'],
#  ['recurrent neural network (RNN)'],
#  ['recursive neural knowledge network (RNKN)',
#   'recursive neural network (RcNN)'],
#  ['SVM'],
#  ['recurrent neural network (RNN)'],
#  ['reinforcement learning (RL)', 'Memory Network', 'neural network (NN)', ''],
#  ['convolutional neural network (CNN)',
#   'recurrent neural network (RNN)',
#   'deep belief network (DBN)'],
#  ['neural network (NN)'],
#  ['transformer'],
#  ['convolutional neural network (CNN)', 'recurrent neural network (RNN)'],
#  ['convolutional neural network (CNN)', 'neural network (NN)'],
#  ['recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN)'],
#  ['convolutional neural network (CNN)'],
#  ['attention network (Attn)', 'graph neural network (GNN)'],
#  ['recurrent neural network (RNN)'],
#  ['neural network (NN)'],
#  ['recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN)', 'reinforcement learning (RL)'],
#  ['SVM'],
#  ['recursive neural network (RcNN)', 'Tensor Product Representation (TPR)'],
#  ['recurrent neural network (RNN)',
#   'convolutional neural network (CNN)',
#   'attention network (Attn)'],
#  ['graph neural network (GNN)'],
#  ['Tensor Product Representation (TPR)', 'recurrent neural network (RNN)'],
#  ['recurrent neural network (RNN)']]

# %%
sym_set=set(sum(sym_list,[]))

# %%
neu_set=set(sum(neu_list,[]))

# %%
neu_set=neu_set-(set(['']))

# %%
neu_set
# Out:
# {'BiDAF',
#  'Gated Neural Network, recurrent neural network (RNN)',
#  'Logical Neural Network',
#  'Memory Network',
#  'SVM',
#  'Tensor Product Representation (TPR)',
#  'TransE',
#  'attention network (Attn)',
#  'convolutional neural network (CNN)',
#  'deep belief network (DBN)',
#  'graph neural network (GNN)',
#  'logic tensor network (LTN)',
#  'long short term memory (LSTM)',
#  'nan',
#  'neural network (NN)',
#  'neuroevolution (NE)',
#  'recurrent neural network (RNN)',
#  'recurrent neural network (RNN), recurrent neural network (RNN)',
#  'recurrent neural network (RNN), recurrent neural network (RNN), tranformer',
#  'recursive neural knowledge network (RNKN)',
#  'recursive neural network (RcNN)',
#  'reinforcement learning (RL)',
#  'transformer'}

# %%
sym_set
# Out:
# {'ConceptNet KG',
#  'Grounding',
#  'Huffman tree',
#  'Natural Logic',
#  'Neutrosophy',
#  'Sequencial decision making',
#  'Vector-symbolic architecture',
#  'binding problem',
#  'case based reasoning (CBR)',
#  'cognitive linguistics',
#  'commonsense knowledge',
#  'constituency parsing',
#  'dependency parsing',
#  'domain specific language (DSL)',
#  'factor graph',
#  'first order logic (FOL)',
#  'fuzzy logic',
#  'fuzzy neural network (FNN)',
#  'fuzzy rules',
#  'graph reasoning',
#  'graph representation',
#  'inductive logic prgramming (ILP)',
#  'knowledge graph (KG)',
#  'logic',
#  'logical connectives',
#  'mamdani fuzzy system (MFS)',
#  'ontology',
#  'path finding and reasoning',
#  'predicate logic',
#  'program synthesis',
#  'relational logic',
#  'rule based',
#  'rule induction',
#  'semantic enrichement',
#  'semantic enrichment',
#  'semantic net',
#  'semantic parsing',
#  'sememe',
#  'symbolic learner',
#  'symbolic node embedding',
#  'symbolic processing',
#  'symbolic representations',
#  'temporal logic',
#  'transductive learning'}

# %%
tup_dict=defaultdict(int)
for i in range(len(sym_list)):
    lists = list(itertools.product(sym_list[i],neu_list[i]))
    
    for j in lists:
        tup_dict[j]+=1

# %%
tup_dict
# Out:
# defaultdict(int,
#             {('first order logic (FOL)', 'long short term memory (LSTM)'): 1,
#              ('first order logic (FOL)', 'TransE'): 1,
#              ('first order logic (FOL)', 'transformer'): 5,
#              ('first order logic (FOL)', 'recurrent neural network (RNN)'): 3,
#              ('Grounding', 'long short term memory (LSTM)'): 1,
#              ('Grounding', 'TransE'): 1,
#              ('Grounding', 'transformer'): 1,
#              ('Grounding', 'recurrent neural network (RNN)'): 1,
#              ('factor graph', 'long short term memory (LSTM)'): 1,
#              ('factor graph', 'TransE'): 1,
#              ('factor graph', 'transformer'): 1,
#              ('factor graph', 'recurrent neural network (RNN)'): 1,
#              ('dependency parsing', 'transformer'): 3,
#              ('semantic parsing', 'graph neural network (GNN)'): 2,
#              ('first order logic (FOL)',
#               'recurrent neural network (RNN), recurrent neural network (RNN)'): 1,
#              ('first order logic (FOL)', 'BiDAF'): 1,
#              ('ontology',
#               'recurrent neural network (RNN), recurrent neural network (RNN)'): 1,
#              ('ontology', 'BiDAF'): 1,
#              ('case based reasoning (CBR)',
#               'Gated Neural Network, recurrent neural network (RNN)'): 1,
#              ('temporal logic',
#               'recurrent neural network (RNN), recurrent neural network (RNN), tranformer'): 1,
#              ('knowledge graph (KG)', 'transformer'): 3,
#              ('graph representation', 'convolutional neural network (CNN)'): 1,
#              ('rule induction', 'Logical Neural Network'): 1,
#              ('first order logic (FOL)', 'Logical Neural Network'): 2,
#              ('ontology', 'Logical Neural Network'): 1,
#              ('semantic parsing', 'Logical Neural Network'): 1,
#              ('rule based', 'Logical Neural Network'): 1,
#              ('Natural Logic', 'transformer'): 1,
#              ('case based reasoning (CBR)', 'TransE'): 1,
#              ('case based reasoning (CBR)', 'transformer'): 1,
#              ('knowledge graph (KG)', 'recurrent neural network (RNN)'): 2,
#              ('ontology', 'recurrent neural network (RNN)'): 2,
#              ('ontology', 'transformer'): 2,
#              ('semantic net', 'nan'): 1,
#              ('knowledge graph (KG)', 'Logical Neural Network'): 1,
#              ('graph representation', 'recurrent neural network (RNN)'): 1,
#              ('semantic net', 'recurrent neural network (RNN)'): 2,
#              ('semantic enrichement', 'recurrent neural network (RNN)'): 1,
#              ('constituency parsing', 'transformer'): 1,
#              ('dependency parsing', 'graph neural network (GNN)'): 1,
#              ('graph reasoning', 'graph neural network (GNN)'): 2,
#              ('graph reasoning', 'transformer'): 1,
#              ('graph representation', 'graph neural network (GNN)'): 3,
#              ('graph representation', 'transformer'): 1,
#              ('Vector-symbolic architecture', 'transformer'): 1,
#              ('semantic net', 'SVM'): 1,
#              ('semantic enrichement', 'neural network (NN)'): 1,
#              ('inductive logic prgramming (ILP)', 'neural network (NN)'): 1,
#              ('first order logic (FOL)', 'neural network (NN)'): 1,
#              ('ontology', 'neural network (NN)'): 1,
#              ('rule based', 'neural network (NN)'): 2,
#              ('fuzzy logic', 'recurrent neural network (RNN)'): 3,
#              ('Vector-symbolic architecture', 'neural network (NN)'): 1,
#              ('path finding and reasoning', 'graph neural network (GNN)'): 1,
#              ('semantic enrichment', 'recurrent neural network (RNN)'): 3,
#              ('first order logic (FOL)', 'logic tensor network (LTN)'): 1,
#              ('knowledge graph (KG)', 'logic tensor network (LTN)'): 1,
#              ('semantic enrichment', 'graph neural network (GNN)'): 1,
#              ('sememe', 'neural network (NN)'): 1,
#              ('symbolic learner', 'SVM'): 1,
#              ('symbolic learner', 'neuroevolution (NE)'): 1,
#              ('symbolic representations', 'SVM'): 1,
#              ('symbolic representations', 'neuroevolution (NE)'): 1,
#              ('ConceptNet KG', 'SVM'): 1,
#              ('ConceptNet KG', 'neuroevolution (NE)'): 1,
#              ('logic', 'recurrent neural network (RNN)'): 1,
#              ('first order logic (FOL)',
#               'recursive neural knowledge network (RNKN)'): 1,
#              ('first order logic (FOL)', 'recursive neural network (RcNN)'): 1,
#              ('Huffman tree', 'recursive neural knowledge network (RNKN)'): 1,
#              ('Huffman tree', 'recursive neural network (RcNN)'): 1,
#              ('commonsense knowledge', 'SVM'): 1,
#              ('graph representation', 'SVM'): 1,
#              ('Sequencial decision making', 'reinforcement learning (RL)'): 1,
#              ('Sequencial decision making', 'Memory Network'): 1,
#              ('Sequencial decision making', 'neural network (NN)'): 1,
#              ('Sequencial decision making', ''): 1,
#              ('predicate logic', 'reinforcement learning (RL)'): 1,
#              ('predicate logic', 'Memory Network'): 1,
#              ('predicate logic', 'neural network (NN)'): 1,
#              ('predicate logic', ''): 1,
#              ('relational logic', 'reinforcement learning (RL)'): 1,
#              ('relational logic', 'Memory Network'): 1,
#              ('relational logic', 'neural network (NN)'): 1,
#              ('relational logic', ''): 1,
#              ('rule based', 'reinforcement learning (RL)'): 1,
#              ('rule based', 'Memory Network'): 1,
#              ('rule based', ''): 1,
#              ('rule induction', 'reinforcement learning (RL)'): 1,
#              ('rule induction', 'Memory Network'): 1,
#              ('rule induction', 'neural network (NN)'): 1,
#              ('rule induction', ''): 1,
#              ('cognitive linguistics', 'reinforcement learning (RL)'): 1,
#              ('cognitive linguistics', 'Memory Network'): 1,
#              ('cognitive linguistics', 'neural network (NN)'): 1,
#              ('cognitive linguistics', ''): 1,
#              ('fuzzy logic', 'convolutional neural network (CNN)'): 2,
#              ('fuzzy logic', 'deep belief network (DBN)'): 1,
#              ('fuzzy neural network (FNN)',
#               'convolutional neural network (CNN)'): 1,
#              ('fuzzy neural network (FNN)',
#               'recurrent neural network (RNN)'): 1,
#              ('fuzzy neural network (FNN)', 'deep belief network (DBN)'): 1,
#              ('logical connectives', 'convolutional neural network (CNN)'): 1,
#              ('logical connectives', 'recurrent neural network (RNN)'): 1,
#              ('logical connectives', 'deep belief network (DBN)'): 1,
#              ('fuzzy logic', 'neural network (NN)'): 2,
#              ('Neutrosophy', 'neural network (NN)'): 1,
#              ('symbolic processing', 'transformer'): 1,
#              ('semantic net', 'convolutional neural network (CNN)'): 1,
#              ('fuzzy rules', 'convolutional neural network (CNN)'): 1,
#              ('fuzzy rules', 'neural network (NN)'): 1,
#              ('mamdani fuzzy system (MFS)',
#               'convolutional neural network (CNN)'): 1,
#              ('mamdani fuzzy system (MFS)', 'neural network (NN)'): 1,
#              ('case based reasoning (CBR)',
#               'recurrent neural network (RNN)'): 1,
#              ('rule based', 'recurrent neural network (RNN)'): 2,
#              ('constituency parsing', 'convolutional neural network (CNN)'): 1,
#              ('graph representation', 'attention network (Attn)'): 1,
#              ('graph reasoning', 'attention network (Attn)'): 1,
#              ('domain specific language (DSL)', 'neural network (NN)'): 1,
#              ('transductive learning', 'neural network (NN)'): 1,
#              ('program synthesis', 'neural network (NN)'): 1,
#              ('fuzzy rules', 'recurrent neural network (RNN)'): 1,
#              ('domain specific language (DSL)',
#               'recurrent neural network (RNN)'): 1,
#              ('domain specific language (DSL)',
#               'reinforcement learning (RL)'): 1,
#              ('rule based', 'SVM'): 1,
#              ('constituency parsing', 'recursive neural network (RcNN)'): 1,
#              ('constituency parsing',
#               'Tensor Product Representation (TPR)'): 1,
#              ('semantic enrichment', 'convolutional neural network (CNN)'): 1,
#              ('semantic enrichment', 'attention network (Attn)'): 1,
#              ('symbolic node embedding', 'graph neural network (GNN)'): 1,
#              ('binding problem', 'Tensor Product Representation (TPR)'): 1,
#              ('binding problem', 'recurrent neural network (RNN)'): 1})

# %%
d=defaultdict(dict)

for i in sym_set:
    inner_dict=defaultdict(dict)
    for j in neu_set:
        inner_dict[j]=tup_dict[(i,j)]
    d[i]=inner_dict
    
assd=pd.DataFrame(d)

# %%
assd
# Out:
#                                                     Huffman tree  \
# deep belief network (DBN)                                      0
# Tensor Product Representation (TPR)                            0
# SVM                                                            0
# reinforcement learning (RL)                                    0
# BiDAF                                                          0
# logic tensor network (LTN)                                     0
# neural network (NN)                                            0
# Logical Neural Network                                         0
# Gated Neural Network, recurrent neural network ...             0
# recurrent neural network (RNN), recurrent neura...             0
# long short term memory (LSTM)                                  0
# TransE                                                         0
# convolutional neural network (CNN)                             0
# graph neural network (GNN)                                     0
# Memory Network                                                 0
# recursive neural network (RcNN)                                1
# recurrent neural network (RNN), recurrent neura...             0
# recurrent neural network (RNN)                                 0
# nan                                                            0
# attention network (Attn)                                       0
# recursive neural knowledge network (RNKN)                      1
# transformer                                                    0
# neuroevolution (NE)                                            0
#
#                                                     symbolic representations  \
# deep belief network (DBN)                                                  0
# Tensor Product Representation (TPR)                                        0
# SVM                                                                        1
# reinforcement learning (RL)                                                0
# BiDAF                                                                      0
# logic tensor network (LTN)                                                 0
# neural network (NN)                                                        0
# Logical Neural Network                                                     0
# Gated Neural Network, recurrent neural network ...                         0
# recurrent neural network (RNN), recurrent neura...                         0
# long short term memory (LSTM)                                              0
# TransE                                                                     0
# convolutional neural network (CNN)                                         0
# graph neural network (GNN)                                                 0
# Memory Network                                                             0
# recursive neural network (RcNN)                                            0
# recurrent neural network (RNN), recurrent neura...                         0
# recurrent neural network (RNN)                                             0
# nan                                                                        0
# attention network (Attn)                                                   0
# recursive neural knowledge network (RNKN)                                  0
# transformer                                                                0
# neuroevolution (NE)                                                        1
#
#                                                     Neutrosophy  \
# deep belief network (DBN)                                     0
# Tensor Product Representation (TPR)                           0
# SVM                                                           0
# reinforcement learning (RL)                                   0
# BiDAF                                                         0
# logic tensor network (LTN)                                    0
# neural network (NN)                                           1
# Logical Neural Network                                        0
# Gated Neural Network, recurrent neural network ...            0
# recurrent neural network (RNN), recurrent neura...            0
# long short term memory (LSTM)                                 0
# TransE                                                        0
# convolutional neural network (CNN)                            0
# graph neural network (GNN)                                    0
# Memory Network                                                0
# recursive neural network (RcNN)                               0
# recurrent neural network (RNN), recurrent neura...            0
# recurrent neural network (RNN)                                0
# nan                                                           0
# attention network (Attn)                                      0
# recursive neural knowledge network (RNKN)                     0
# transformer                                                   0
# neuroevolution (NE)                                           0
#
#                                                     semantic enrichment  \
# deep belief network (DBN)                                             0
# Tensor Product Representation (TPR)                                   0
# SVM                                                                   0
# reinforcement learning (RL)                                           0
# BiDAF                                                                 0
# logic tensor network (LTN)                                            0
# neural network (NN)                                                   0
# Logical Neural Network                                                0
# Gated Neural Network, recurrent neural network ...                    0
# recurrent neural network (RNN), recurrent neura...                    0
# long short term memory (LSTM)                                         0
# TransE                                                                0
# convolutional neural network (CNN)                                    1
# graph neural network (GNN)                                            1
# Memory Network                                                        0
# recursive neural network (RcNN)                                       0
# recurrent neural network (RNN), recurrent neura...                    0
# recurrent neural network (RNN)                                        3
# nan                                                                   0
# attention network (Attn)                                              1
# recursive neural knowledge network (RNKN)                             0
# transformer                                                           0
# neuroevolution (NE)                                                   0
#
#                                                     binding problem  \
# deep belief network (DBN)                                         0
# Tensor Product Representation (TPR)                               1
# SVM                                                               0
# reinforcement learning (RL)                                       0
# BiDAF                                                             0
# logic tensor network (LTN)                                        0
# neural network (NN)                                               0
# Logical Neural Network                                            0
# Gated Neural Network, recurrent neural network ...                0
# recurrent neural network (RNN), recurrent neura...                0
# long short term memory (LSTM)                                     0
# TransE                                                            0
# convolutional neural network (CNN)                                0
# graph neural network (GNN)                                        0
# Memory Network                                                    0
# recursive neural network (RcNN)                                   0
# recurrent neural network (RNN), recurrent neura...                0
# recurrent neural network (RNN)                                    1
# nan                                                               0
# attention network (Attn)                                          0
# recursive neural knowledge network (RNKN)                         0
# transformer                                                       0
# neuroevolution (NE)                                               0
#
#                                                     graph reasoning  \
# deep belief network (DBN)                                         0
# Tensor Product Representation (TPR)                               0
# SVM                                                               0
# reinforcement learning (RL)                                       0
# BiDAF                                                             0
# logic tensor network (LTN)                                        0
# neural network (NN)                                               0
# Logical Neural Network                                            0
# Gated Neural Network, recurrent neural network ...                0
# recurrent neural network (RNN), recurrent neura...                0
# long short term memory (LSTM)                                     0
# TransE                                                            0
# convolutional neural network (CNN)                                0
# graph neural network (GNN)                                        2
# Memory Network                                                    0
# recursive neural network (RcNN)                                   0
# recurrent neural network (RNN), recurrent neura...                0
# recurrent neural network (RNN)                                    0
# nan                                                               0
# attention network (Attn)                                          1
# recursive neural knowledge network (RNKN)                         0
# transformer                                                       1
# neuroevolution (NE)                                               0
#
#                                                     inductive logic prgramming (ILP)  \
# deep belief network (DBN)                                                          0
# Tensor Product Representation (TPR)                                                0
# SVM                                                                                0
# reinforcement learning (RL)                                                        0
# BiDAF                                                                              0
# logic tensor network (LTN)                                                         0
# neural network (NN)                                                                1
# Logical Neural Network                                                             0
# Gated Neural Network, recurrent neural network ...                                 0
# recurrent neural network (RNN), recurrent neura...                                 0
# long short term memory (LSTM)                                                      0
# TransE                                                                             0
# convolutional neural network (CNN)                                                 0
# graph neural network (GNN)                                                         0
# Memory Network                                                                     0
# recursive neural network (RcNN)                                                    0
# recurrent neural network (RNN), recurrent neura...                                 0
# recurrent neural network (RNN)                                                     0
# nan                                                                                0
# attention network (Attn)                                                           0
# recursive neural knowledge network (RNKN)                                          0
# transformer                                                                        0
# neuroevolution (NE)                                                                0
#
#                                                     knowledge graph (KG)  \
# deep belief network (DBN)                                              0
# Tensor Product Representation (TPR)                                    0
# SVM                                                                    0
# reinforcement learning (RL)                                            0
# BiDAF                                                                  0
# logic tensor network (LTN)                                             1
# neural network (NN)                                                    0
# Logical Neural Network                                                 1
# Gated Neural Network, recurrent neural network ...                     0
# recurrent neural network (RNN), recurrent neura...                     0
# long short term memory (LSTM)                                          0
# TransE                                                                 0
# convolutional neural network (CNN)                                     0
# graph neural network (GNN)                                             0
# Memory Network                                                         0
# recursive neural network (RcNN)                                        0
# recurrent neural network (RNN), recurrent neura...                     0
# recurrent neural network (RNN)                                         2
# nan                                                                    0
# attention network (Attn)                                               0
# recursive neural knowledge network (RNKN)                              0
# transformer                                                            3
# neuroevolution (NE)                                                    0
#
#                                                     dependency parsing  \
# deep belief network (DBN)                                            0
# Tensor Product Representation (TPR)                                  0
# SVM                                                                  0
# reinforcement learning (RL)                                          0
# BiDAF                                                                0
# logic tensor network (LTN)                                           0
# neural network (NN)                                                  0
# Logical Neural Network                                               0
# Gated Neural Network, recurrent neural network ...                   0
# recurrent neural network (RNN), recurrent neura...                   0
# long short term memory (LSTM)                                        0
# TransE                                                               0
# convolutional neural network (CNN)                                   0
# graph neural network (GNN)                                           1
# Memory Network                                                       0
# recursive neural network (RcNN)                                      0
# recurrent neural network (RNN), recurrent neura...                   0
# recurrent neural network (RNN)                                       0
# nan                                                                  0
# attention network (Attn)                                             0
# recursive neural knowledge network (RNKN)                            0
# transformer                                                          3
# neuroevolution (NE)                                                  0
#
#                                                     Natural Logic  ...  \
# deep belief network (DBN)                                       0  ...
# Tensor Product Representation (TPR)                             0  ...
# SVM                                                             0  ...
# reinforcement learning (RL)                                     0  ...
# BiDAF                                                           0  ...
# logic tensor network (LTN)                                      0  ...
# neural network (NN)                                             0  ...
# Logical Neural Network                                          0  ...
# Gated Neural Network, recurrent neural network ...              0  ...
# recurrent neural network (RNN), recurrent neura...              0  ...
# long short term memory (LSTM)                                   0  ...
# TransE                                                          0  ...
# convolutional neural network (CNN)                              0  ...
# graph neural network (GNN)                                      0  ...
# Memory Network                                                  0  ...
# recursive neural network (RcNN)                                 0  ...
# recurrent neural network (RNN), recurrent neura...              0  ...
# recurrent neural network (RNN)                                  0  ...
# nan                                                             0  ...
# attention network (Attn)                                        0  ...
# recursive neural knowledge network (RNKN)                       0  ...
# transformer                                                     1  ...
# neuroevolution (NE)                                             0  ...
#
#                                                     symbolic learner  \
# deep belief network (DBN)                                          0
# Tensor Product Representation (TPR)                                0
# SVM                                                                1
# reinforcement learning (RL)                                        0
# BiDAF                                                              0
# logic tensor network (LTN)                                         0
# neural network (NN)                                                0
# Logical Neural Network                                             0
# Gated Neural Network, recurrent neural network ...                 0
# recurrent neural network (RNN), recurrent neura...                 0
# long short term memory (LSTM)                                      0
# TransE                                                             0
# convolutional neural network (CNN)                                 0
# graph neural network (GNN)                                         0
# Memory Network                                                     0
# recursive neural network (RcNN)                                    0
# recurrent neural network (RNN), recurrent neura...                 0
# recurrent neural network (RNN)                                     0
# nan                                                                0
# attention network (Attn)                                           0
# recursive neural knowledge network (RNKN)                          0
# transformer                                                        0
# neuroevolution (NE)                                                1
#
#                                                     cognitive linguistics  \
# deep belief network (DBN)                                               0
# Tensor Product Representation (TPR)                                     0
# SVM                                                                     0
# reinforcement learning (RL)                                             1
# BiDAF                                                                   0
# logic tensor network (LTN)                                              0
# neural network (NN)                                                     1
# Logical Neural Network                                                  0
# Gated Neural Network, recurrent neural network ...                      0
# recurrent neural network (RNN), recurrent neura...                      0
# long short term memory (LSTM)                                           0
# TransE                                                                  0
# convolutional neural network (CNN)                                      0
# graph neural network (GNN)                                              0
# Memory Network                                                          1
# recursive neural network (RcNN)                                         0
# recurrent neural network (RNN), recurrent neura...                      0
# recurrent neural network (RNN)                                          0
# nan                                                                     0
# attention network (Attn)                                                0
# recursive neural knowledge network (RNKN)                               0
# transformer                                                             0
# neuroevolution (NE)                                                     0
#
#                                                     graph representation  \
# deep belief network (DBN)                                              0
# Tensor Product Representation (TPR)                                    0
# SVM                                                                    1
# reinforcement learning (RL)                                            0
# BiDAF                                                                  0
# logic tensor network (LTN)                                             0
# neural network (NN)                                                    0
# Logical Neural Network                                                 0
# Gated Neural Network, recurrent neural network ...                     0
# recurrent neural network (RNN), recurrent neura...                     0
# long short term memory (LSTM)                                          0
# TransE                                                                 0
# convolutional neural network (CNN)                                     1
# graph neural network (GNN)                                             3
# Memory Network                                                         0
# recursive neural network (RcNN)                                        0
# recurrent neural network (RNN), recurrent neura...                     0
# recurrent neural network (RNN)                                         1
# nan                                                                    0
# attention network (Attn)                                               1
# recursive neural knowledge network (RNKN)                              0
# transformer                                                            1
# neuroevolution (NE)                                                    0
#
#                                                     mamdani fuzzy system (MFS)  \
# deep belief network (DBN)                                                    0
# Tensor Product Representation (TPR)                                          0
# SVM                                                                          0
# reinforcement learning (RL)                                                  0
# BiDAF                                                                        0
# logic tensor network (LTN)                                                   0
# neural network (NN)                                                          1
# Logical Neural Network                                                       0
# Gated Neural Network, recurrent neural network ...                           0
# recurrent neural network (RNN), recurrent neura...                           0
# long short term memory (LSTM)                                                0
# TransE                                                                       0
# convolutional neural network (CNN)                                           1
# graph neural network (GNN)                                                   0
# Memory Network                                                               0
# recursive neural network (RcNN)                                              0
# recurrent neural network (RNN), recurrent neura...                           0
# recurrent neural network (RNN)                                               0
# nan                                                                          0
# attention network (Attn)                                                     0
# recursive neural knowledge network (RNKN)                                    0
# transformer                                                                  0
# neuroevolution (NE)                                                          0
#
#                                                     symbolic processing  \
# deep belief network (DBN)                                             0
# Tensor Product Representation (TPR)                                   0
# SVM                                                                   0
# reinforcement learning (RL)                                           0
# BiDAF                                                                 0
# logic tensor network (LTN)                                            0
# neural network (NN)                                                   0
# Logical Neural Network                                                0
# Gated Neural Network, recurrent neural network ...                    0
# recurrent neural network (RNN), recurrent neura...                    0
# long short term memory (LSTM)                                         0
# TransE                                                                0
# convolutional neural network (CNN)                                    0
# graph neural network (GNN)                                            0
# Memory Network                                                        0
# recursive neural network (RcNN)                                       0
# recurrent neural network (RNN), recurrent neura...                    0
# recurrent neural network (RNN)                                        0
# nan                                                                   0
# attention network (Attn)                                              0
# recursive neural knowledge network (RNKN)                             0
# transformer                                                           1
# neuroevolution (NE)                                                   0
#
#                                                     semantic enrichement  \
# deep belief network (DBN)                                              0
# Tensor Product Representation (TPR)                                    0
# SVM                                                                    0
# reinforcement learning (RL)                                            0
# BiDAF                                                                  0
# logic tensor network (LTN)                                             0
# neural network (NN)                                                    1
# Logical Neural Network                                                 0
# Gated Neural Network, recurrent neural network ...                     0
# recurrent neural network (RNN), recurrent neura...                     0
# long short term memory (LSTM)                                          0
# TransE                                                                 0
# convolutional neural network (CNN)                                     0
# graph neural network (GNN)                                             0
# Memory Network                                                         0
# recursive neural network (RcNN)                                        0
# recurrent neural network (RNN), recurrent neura...                     0
# recurrent neural network (RNN)                                         1
# nan                                                                    0
# attention network (Attn)                                               0
# recursive neural knowledge network (RNKN)                              0
# transformer                                                            0
# neuroevolution (NE)                                                    0
#
#                                                     logic  \
# deep belief network (DBN)                               0
# Tensor Product Representation (TPR)                     0
# SVM                                                     0
# reinforcement learning (RL)                             0
# BiDAF                                                   0
# logic tensor network (LTN)                              0
# neural network (NN)                                     0
# Logical Neural Network                                  0
# Gated Neural Network, recurrent neural network ...      0
# recurrent neural network (RNN), recurrent neura...      0
# long short term memory (LSTM)                           0
# TransE                                                  0
# convolutional neural network (CNN)                      0
# graph neural network (GNN)                              0
# Memory Network                                          0
# recursive neural network (RcNN)                         0
# recurrent neural network (RNN), recurrent neura...      0
# recurrent neural network (RNN)                          1
# nan                                                     0
# attention network (Attn)                                0
# recursive neural knowledge network (RNKN)               0
# transformer                                             0
# neuroevolution (NE)                                     0
#
#                                                     constituency parsing  \
# deep belief network (DBN)                                              0
# Tensor Product Representation (TPR)                                    1
# SVM                                                                    0
# reinforcement learning (RL)                                            0
# BiDAF                                                                  0
# logic tensor network (LTN)                                             0
# neural network (NN)                                                    0
# Logical Neural Network                                                 0
# Gated Neural Network, recurrent neural network ...                     0
# recurrent neural network (RNN), recurrent neura...                     0
# long short term memory (LSTM)                                          0
# TransE                                                                 0
# convolutional neural network (CNN)                                     1
# graph neural network (GNN)                                             0
# Memory Network                                                         0
# recursive neural network (RcNN)                                        1
# recurrent neural network (RNN), recurrent neura...                     0
# recurrent neural network (RNN)                                         0
# nan                                                                    0
# attention network (Attn)                                               0
# recursive neural knowledge network (RNKN)                              0
# transformer                                                            1
# neuroevolution (NE)                                                    0
#
#                                                     semantic parsing  \
# deep belief network (DBN)                                          0
# Tensor Product Representation (TPR)                                0
# SVM                                                                0
# reinforcement learning (RL)                                        0
# BiDAF                                                              0
# logic tensor network (LTN)                                         0
# neural network (NN)                                                0
# Logical Neural Network                                             1
# Gated Neural Network, recurrent neural network ...                 0
# recurrent neural network (RNN), recurrent neura...                 0
# long short term memory (LSTM)                                      0
# TransE                                                             0
# convolutional neural network (CNN)                                 0
# graph neural network (GNN)                                         2
# Memory Network                                                     0
# recursive neural network (RcNN)                                    0
# recurrent neural network (RNN), recurrent neura...                 0
# recurrent neural network (RNN)                                     0
# nan                                                                0
# attention network (Attn)                                           0
# recursive neural knowledge network (RNKN)                          0
# transformer                                                        0
# neuroevolution (NE)                                                0
#
#                                                     program synthesis
# deep belief network (DBN)                                           0
# Tensor Product Representation (TPR)                                 0
# SVM                                                                 0
# reinforcement learning (RL)                                         0
# BiDAF                                                               0
# logic tensor network (LTN)                                          0
# neural network (NN)                                                 1
# Logical Neural Network                                              0
# Gated Neural Network, recurrent neural network ...                  0
# recurrent neural network (RNN), recurrent neura...                  0
# long short term memory (LSTM)                                       0
# TransE                                                              0
# convolutional neural network (CNN)                                  0
# graph neural network (GNN)                                          0
# Memory Network                                                      0
# recursive neural network (RcNN)                                     0
# recurrent neural network (RNN), recurrent neura...                  0
# recurrent neural network (RNN)                                      0
# nan                                                                 0
# attention network (Attn)                                            0
# recursive neural knowledge network (RNKN)                           0
# transformer                                                         0
# neuroevolution (NE)                                                 0
#
# [23 rows x 44 columns]

# %%
plt.style.use('presentation.mplstyle')
mpl.matplotlib_fname()
fig, ax = plt.subplots(figsize=(15, 8))
color_map = plt.cm.get_cmap('magma')
reversed_color_map = color_map.reversed()

plt.hlines(y=np.arange(0, len(assd.index), 1), xmin=np.full(len(assd.index),0), xmax=np.full(len(assd.index),len(assd.columns)), color="#cccccc", linewidth=.25)
plt.vlines(x=np.arange(0, len(assd.columns), 1), ymin=np.full(len(assd.columns),0), ymax=np.full(len(assd.columns),len(assd.index)), color="#cccccc",linewidth=.25)
plt.yticks(np.arange(0.5, len(assd.index), 1), assd.index)
plt.xticks(np.arange(0.5, len(assd.columns), 1), assd.columns, rotation=90)
plt.ylabel("Neural")
plt.xlabel("Symbolic")
plt.title("Neural-Symbolic")

graph=plt.pcolor(assd, cmap=reversed_color_map)
cb = fig.colorbar(graph)
# cb.set_label('Support', rotation=0, va='bottom')
cb.outline.set_visible(False)
plt.show()

# %%
df.columns
# Out:
# Index(['Doc type', 'citation', 'Title', 'Abstract', 'Scopus Hash ID', 'DOI',
#        'Journal/Conference', 'Year', 'Business Use Case',
#        'Technical Application', 'Type of Learning', 'Key-intake',
#        'Contribution', 'Authors Definition of NeSy', 'Symbolic terms',
#        'Neural terms', 'NeSy Category', 'Kautz category', 'Datasets',
#        'Model description', 'Evaluation Metrics', 'Reported Score',
#        'Study Quality', 'Comments', 'MISC',
#        'leverages natural language structure',
#        'leverages relational structure', 'Knowledge representation',
#        'implicit vs explicit', 'reasoning',
#        'out-of-distribution generalization', 'interpretability',
#        'reduced data', 'transferability',
#        'NeSy (check if the authors label their work as NeSy)'],
#       dtype='object')

# %%
df_seq = df[df['NeSy Category'] == 'sequential']
df_seq['Technical Application'].value_counts()
# Out:
# classification            16
# reasoning                  2
# information extraction     2
# similarity                 1
# generative                 1
# inference                  1
# Name: Technical Application, dtype: int64

# %%
df_cat_goals = df[['NeSy Category']]

# %%
df.groupby('NeSy Category').count()
# Out:
#                Doc type  citation  Title  Abstract  Scopus Hash ID  DOI  \
# NeSy Category
# compiled             18        18     18         9              18   11
# cooperative          13        13     13         8              12   11
# nested                7         7      7         5               6    6
# sequential           23        23     23         8              22   19
#
#                Journal/Conference  Year  Business Use Case  \
# NeSy Category
# compiled                        9    18                 18
# cooperative                     7    13                 13
# nested                          4     7                  7
# sequential                     16    23                 23
#
#                Technical Application  ...  \
# NeSy Category                         ...
# compiled                          18  ...
# cooperative                       13  ...
# nested                             7  ...
# sequential                        23  ...
#
#                leverages natural language structure  \
# NeSy Category
# compiled                                         18
# cooperative                                      13
# nested                                            7
# sequential                                       23
#
#                leverages relational structure  Knowledge representation  \
# NeSy Category
# compiled                                   18                        18
# cooperative                                13                        12
# nested                                      7                         7
# sequential                                 23                        23
#
#                implicit vs explicit  reasoning  \
# NeSy Category
# compiled                         18         18
# cooperative                      12         13
# nested                            7          7
# sequential                       23         23
#
#                out-of-distribution generalization  interpretability  \
# NeSy Category
# compiled                                       18                18
# cooperative                                    13                13
# nested                                          7                 7
# sequential                                     23                23
#
#                reduced data  transferability  \
# NeSy Category
# compiled                 18               18
# cooperative              13               13
# nested                    7                7
# sequential               23               23
#
#                NeSy (check if the authors label their work as NeSy)
# NeSy Category
# compiled                                                      18
# cooperative                                                   13
# nested                                                         7
# sequential                                                    23
#
# [4 rows x 34 columns]

# %% [markdown]
# # STOP HERE
# The rest has to do with secondary studies, ie rerefence papers. We are not reviewing these.

# %% [markdown]
# # Get all the references for all papers

# %%
# let's get the abstracts from scopus of all the articles we included. 
# We'll do a search on scopus for EID and DOI
# 'Scopus Hash ID', 'DOI',

df[['Scopus Hash ID','DOI']]
# Out:
#         Scopus Hash ID                                DOI
# 0   2-s2.0-85064856751       10.1007/978-3-030-15719-7_13
# 1   2-s2.0-85067488804       10.1007/978-3-030-20521-8_54
# 2   2-s2.0-85072850367       10.1007/978-3-030-30490-4_16
# 3   2-s2.0-85075592929       10.1007/978-3-030-31095-0_11
# 4   2-s2.0-85096590382       10.1007/978-3-030-61609-0_51
# 5   2-s2.0-85113718164       10.1007/978-3-030-82147-0_34
# 6             2FCUJH2G          10.1007/s10462-010-9188-4
# 7             JN4IZETG         10.1007/s10994-021-05968-x
# 8             7MMJY5BM         10.1007/s13218-019-00601-5
# 9             7Q5JRVK2       10.1016/j.artint.2015.08.011
# 10            JGU2SECC       10.1016/j.artmed.2019.101772
# 11            7YX447XS         10.1016/j.eswa.2016.01.007
# 12            GS3TRUYZ       10.1016/j.neucom.2017.10.010
# 13            2PNFHS7L       10.1016/j.neucom.2021.02.021
# 14            NB39QA35       10.1016/j.neunet.2018.06.012
# 15            B47SSE6P       10.1016/j.patrec.2019.04.024
# 16            ACDMDN8W         10.1108/IJWIS-11-2020-0067
# 17            EGI547RA        10.1109/ACCESS.2019.2948081
# 18            3YFVRRKE        10.1109/ACCESS.2020.2972751
# 19            BAMGPUCX        10.1109/ACCESS.2021.3053917
# 20  2-s2.0-85081087069           10.1109/ICTAI.2019.00027
# 21  2-s2.0-85073214635         10.1109/IJCNN.2019.8851875
# 22  2-s2.0-85083026315  10.1109/INDICON47234.2019.9028985
# 23            RDSQSBN7         10.1109/TASLP.2021.3082295
# 24  2-s2.0-85087103850            10.1145/3391274.3393636
# 25  2-s2.0-85108908770            10.1145/3453483.3454047
# 26  2-s2.0-85070277710        10.23919/MIPRO.2019.8756929
# 27  2-s2.0-85083954234                                NaN
# 28  2-s2.0-85085038180                                NaN
# 29  2-s2.0-85080593464                                NaN
# 30  2-s2.0-85081092649                                NaN
# 31  2-s2.0-85085049747                                NaN
# 32  2-s2.0-85105153943                                NaN
# 33  2-s2.0-85106687657                                NaN

# %% [markdown]
# The two studies missing a DOI:
# * 2-s2.0-85106687657
# * 2-s2.0-85105153943
#
# Scopus search which makes references(25)scopus.csv:
# <pre>
# DOI ("10.1007/978-3-030-48279-4_55" OR "10.1016/j.neunet.2016.09.001"  OR  "10.1108/IJWIS-11-2020-0067"  OR  "10.1007/s10994-021-05968-x"  OR
# "10.1016/j.eswa.2016.01.007"  OR "10.1016/j.neucom.2020.12.040"  OR  "10.1007/s10462-010-9188-4"  OR  "10.1016/j.patrec.2019.04.024"  OR
# "10.1016/j.neucom.2021.02.021"  OR "10.1109/ACCESS.2020.2972751"  OR  "10.1016/j.neunet.2018.06.012"  OR  "10.1016/j.artmed.2019.101772"  OR
# "10.1007/978-3-030-61609-0_51"  OR "10.1109/ACCESS.2019.2948081"  OR  "10.1109/TASLP.2021.3082295"  OR  "10.1109/ACCESS.2020.3019586"  OR
# "10.1016/j.artint.2015.08.011"  OR "10.1007/978-3-030-82147-0_34"  OR  "10.1016/j.neucom.2017.10.010"  OR  "10.1109/ACCESS.2021.3053917"  OR
# "10.1007/s13218-019-00601-5"  OR "10.1007/s12065-019-00301-x"  OR  "10.1145/3453483.3454047" OR "10.1016/j.neunet.2012.02.013" OR
# "10.1007/s11042-019-08125-8")
#
# OR  EID ( "2-s2.0-85106687657"  OR  "2-s2.0-85105153943" )
# </pre>

# %%
# get the articles
all_papers=pd.read_csv('Data/scopus(27).csv')

# %%
all_papers=all_papers[['EID','Title','References']]

# %%
len(all_papers) #.columns
# should be 25!
# Out:
# 27

# %%
len(all_papers['Title'].unique())
# should be 25!
# Out:
# 27

# %%
all_papers=all_papers.drop_duplicates(subset="Title")

# %%
all_papers.columns
# Out:
# Index(['EID', 'Title', 'References'], dtype='object')

# %%
# references are separated by a semi-colon. Create a list by splitting on ;
all_papers['References']=all_papers['References'].str.split(pat=";")

# %%
# put each citation in its own row
all_papers=all_papers.explode('References')

# %%
all_papers=all_papers.reset_index(drop=True)

# %%
all_papers.to_csv('Data/references(27)exploded.csv')

# %%
# add scopus data to references

refs_df = pd.read_csv('Data/references(27)scopus.csv')

# %%
# extract just the relevant fields
refs_df=refs_df[['Authors','Title','Abstract','DOI','Year','Cited by','Author Keywords',
         'Index Keywords','EID']]

# %%
refs_df.query('Year > 0')['Year'].hist()
# Out:
# <AxesSubplot:>

# %%
years=refs_df.query('Year > 0')['Year'].value_counts()
years_arr=list(zip(years.index, years.values))
sorted(years_arr, key=lambda t: -t[0])
# Out:
# [(2020, 61),
#  (2019, 93),
#  (2018, 99),
#  (2017, 103),
#  (2016, 76),
#  (2015, 77),
#  (2014, 54),
#  (2013, 55),
#  (2012, 29),
#  (2011, 33),
#  (2010, 30),
#  (2009, 25),
#  (2008, 35),
#  (2007, 16),
#  (2006, 25),
#  (2005, 20),
#  (2004, 17),
#  (2003, 21),
#  (2002, 17),
#  (2001, 15),
#  (2000, 14),
#  (1999, 14),
#  (1998, 12),
#  (1997, 12),
#  (1996, 9),
#  (1995, 15),
#  (1994, 8),
#  (1993, 1),
#  (1992, 5),
#  (1991, 10),
#  (1990, 11),
#  (1989, 5),
#  (1988, 2),
#  (1987, 5),
#  (1986, 6),
#  (1985, 1),
#  (1983, 2),
#  (1982, 1),
#  (1980, 2),
#  (1979, 1),
#  (1975, 4),
#  (1974, 4),
#  (1973, 1),
#  (1972, 2),
#  (1970, 1),
#  (1969, 3),
#  (1968, 3),
#  (1967, 2),
#  (1966, 1),
#  (1965, 2),
#  (1962, 2),
#  (1958, 1),
#  (1957, 1),
#  (1956, 2),
#  (1953, 1),
#  (1952, 1),
#  (1949, 1),
#  (1947, 1),
#  (1943, 1),
#  (1937, 1),
#  (1931, 1),
#  (1926, 1),
#  (1810, 1)]

# %%
# Extracts ref titles from the references
all_papers['ref_title']=all_papers['References'].str.extract('(.*?)\(\d+\)', expand=True) #.reset_index(level=0, drop=True)

# %%
pd.set_option('display.max_colwidth', None)
# all_papers['ref_title']

# %%
# split on comma and get last element. that's the title.
all_papers['ref_title']=all_papers['ref_title'].str.split(pat=",").str[-1]

# %%
all_papers['ref_title']=all_papers['ref_title'].str.strip()

# %%
# join on title with scopus reference df - refs_df
all_papers
# Out:
#                      EID  \
# 0     2-s2.0-85106687657
# 1     2-s2.0-85106687657
# 2     2-s2.0-85106687657
# 3     2-s2.0-85106687657
# 4     2-s2.0-85106687657
# ...                  ...
# 1149  2-s2.0-85106847388
# 1150  2-s2.0-85106847388
# 1151  2-s2.0-85106847388
# 1152  2-s2.0-85106847388
# 1153  2-s2.0-85106847388
#
#                                                                             Title  \
# 0                            Just Add Functions: A Neural-Symbolic Language Model
# 1                            Just Add Functions: A Neural-Symbolic Language Model
# 2                            Just Add Functions: A Neural-Symbolic Language Model
# 3                            Just Add Functions: A Neural-Symbolic Language Model
# 4                            Just Add Functions: A Neural-Symbolic Language Model
# ...                                                                           ...
# 1149  Sentence-Level Classification Using Parallel Fuzzy Deep Learning Classifier
# 1150  Sentence-Level Classification Using Parallel Fuzzy Deep Learning Classifier
# 1151  Sentence-Level Classification Using Parallel Fuzzy Deep Learning Classifier
# 1152  Sentence-Level Classification Using Parallel Fuzzy Deep Learning Classifier
# 1153  Sentence-Level Classification Using Parallel Fuzzy Deep Learning Classifier
#
#                                                                                                                                                                                                                             References  \
# 0                                                                                                                         Ahn, S., Choi, H., Pärnamaa, T., Bengio, Y., (2017) A neural knowledge language model, , CoRR abs/1608.00318
# 1                                                                                                                      Bengio, Y., Schwenk, H., Senecal, J.-S., Morin, F., Gauvain, J.-L., (2006) Neural probabilistic language models
# 2      Besold, T. R., d'Avila Garcez, A. S., Bader, S., Bowman, H., Domingos, P. M., Hitzler, P., Kühnberger, K.-U., Zaverucha, G., (2017) Neural-symbolic learning and reasoning: A survey and interpretation, , ArXiv abs/1711.03902
# 3                                                          Chelba, C., Mikolov, T., Schuster, M., Ge, Q., Brants, T., Koehn, P., One billion word benchmark for measuring progress in statistical language modeling (2013) INTERSPEECH
# 4                                                                                                                                                    Firth, J. R., (1957) A synopsis of linguistic theory 1930-55, pp. 1-32. , 1952 59
# ...                                                                                                                                                                                                                                ...
# 1149                                                                                                       (2020) COVID-19-Sentiments India[20/03/20-31/05/20], , https://kaggle.com/abhaydhiman/covid19-sentiments, Accessed: Dec. 30
# 1150          Gangadharan, V., Gupta, D., Amritha, L., Athira, T.A., Paraphrase detection using deep neural network based word embedding techniques (2020) Proc. 4th Int. Conf. Trends Electron. Informat. (ICOEI), pp. 517-521. , Jun
# 1151                                                         Pennington, J., Socher, R., Manning, C., Glove: Global vectors for word representation (2014) Proc. Conf. Empirical Methods Natural Lang. Process. (EMNLP), pp. 1532-1543
# 1152                                Mikolov, T., Sutskever, I., Chen, K., Corrado, G., Dean, J., (2013) Distributed Representations of Words and Phrases and Their Compositionality, , http://arxiv.org/abs/1310.4546, arXiv:1310.4546
# 1153                                                      Es-Sabery, F., Hair, A., Big data solutions proposed for cluster computing systems challenges: A survey (2020) Proc. 3rd Int. Conf. Netw., Inf. Syst. Secur., pp. 1-7. , Mar
#
#                                                                                ref_title
# 0
# 1
# 2
# 3     One billion word benchmark for measuring progress in statistical language modeling
# 4
# ...                                                                                  ...
# 1149
# 1150      Paraphrase detection using deep neural network based word embedding techniques
# 1151                                       Glove: Global vectors for word representation
# 1152
# 1153      Big data solutions proposed for cluster computing systems challenges: A survey
#
# [1154 rows x 4 columns]

# %%
new_df = pd.merge(all_papers, refs_df,  how='left', left_on='ref_title', right_on = 'Title')

# %%
len(new_df[new_df['Title_y'].notnull()])
# Out:
# 556

# %%
new_df.to_csv('Data/references(27)merged.csv', index=False)

# %%
len(new_df)
# Out:
# 1169

# %%
new_df.columns
# Out:
# Index(['EID_x', 'Title_x', 'References', 'ref_title', 'Authors', 'Title_y',
#        'Abstract', 'DOI', 'Year', 'Cited by', 'Author Keywords',
#        'Index Keywords', 'EID_y'],
#       dtype='object')

# %%
qq_df = pd.read_csv('Data/qq(27).csv')

# %%
qq_df = qq_df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8', 'Q9','Q10']]

# %%
qq_df.describe()
# Out:
#               Q1         Q2         Q3         Q4         Q6         Q7  \
# count  26.000000  26.000000  26.000000  26.000000  26.000000  26.000000
# mean    0.826923   0.846154   0.788462   0.846154   0.865385   0.596154
# std     0.314398   0.308844   0.378763   0.339683   0.301917   0.490290
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.625000   1.000000   0.625000   1.000000   1.000000   0.000000
# 50%     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 75%     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               Q8         Q9        Q10
# count  25.000000  27.000000  27.000000
# mean    0.100000   0.185185   0.240741
# std     0.288675   0.395847   0.401209
# min     0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.500000
# max     1.000000   1.000000   1.000000

# %% [markdown]
# # Annotated reference papers
# In the first screening, the papers have been marked for inclusion based on title/abstract

# %%
ref_ann_df = pd.read_csv('Data/references(27)merged_annotated.csv')

# %%
ref_ann_df.columns
# Out:
# Index(['EID_x (of the original paper)', 'Title_x (of the original paper)',
#        'References (from the original 27 papers)',
#        'ref_title (extracted using regex from References from the original papers)',
#        'Abstract', ' keep (NeSy)', 'keep (background)', 'Kyle', 'Aparna',
#        'Title_y (from scopus)', 'EID_y', 'DOI', 'Unnamed: 12', 'Year',
#        'Cited by', 'Authors', 'Author Keywords', 'Index Keywords'],
#       dtype='object')
